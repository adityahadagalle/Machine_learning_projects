# %% [markdown]
# <a href="https://colab.research.google.com/github/adityahadagalle/Machine_learning_projects/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("Mall Customers.xlsx")
df=df.drop(columns="CustomerID")
df.head()
# Out:
#   Gender  Age   Education  Marital Status  Annual Income (k$)  \
# 0      M   19  High School        Married                  15
# 1      M   21     Graduate         Single                  15
# 2      F   20     Graduate        Married                  16
# 3      F   23  High School        Unknown                  16
# 4      F   31   Uneducated        Married                  17
#
#    Spending Score (1-100)
# 0                      39
# 1                      81
# 2                       6
# 3                      77
# 4                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Education               200 non-null    object
#  3   Marital Status          200 non-null    object
#  4   Annual Income (k$)      200 non-null    int64
#  5   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 9.5+ KB

# %%
df["Education "].value_counts()
# Out:
# Education
# Graduate         67
# High School      40
# Uneducated       31
# Unknown          26
# College          17
# Doctorate        11
# Post-Graduate     8
# Name: count, dtype: int64

# %%
df["Gender"]=df["Gender"].map({'M':1,"F":0})

# %%
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Education ', 'Marital Status', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sns.scatterplot(
    x='Annual Income (k$)',
    y='Spending Score (1-100)',
    hue='Cluster',
    palette='Set1',
    data=df
)
plt.show()

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %% [markdown]
# Elbow point analysis

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.xlabel("No. of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=y_kmeans)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=200, c='red')
plt.show()

# %% [markdown]
# silhouette_score Analysis

# %%
from sklearn.metrics import silhouette_score

for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    labels = kmeans.fit_predict(X)
    print(k, (silhouette_score(X, labels)))
# Out:
# 2 0.39564531743995546
# 3 0.46761358158775435
# 4 0.4931963109249047
# 5 0.5532176107575425
# 6 0.5379675585622219
# 7 0.4544116530735583
# 8 0.45407359550241166
# 9 0.43362754625776595

# %%
df['Cluster'] = y_kmeans
df.head()
# Out:
#    Gender  Age   Education  Marital Status  Annual Income (k$)  \
# 0       1   19  High School        Married                  15
# 1       1   21     Graduate         Single                  15
# 2       0   20     Graduate        Married                  16
# 3       0   23  High School        Unknown                  16
# 4       0   31   Uneducated        Married                  17
#
#    Spending Score (1-100)  Cluster
# 0                      39        3
# 1                      81        4
# 2                       6        3
# 3                      77        4
# 4                      40        3
